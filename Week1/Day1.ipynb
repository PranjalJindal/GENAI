# %%
from openai import OpenAI

openai = OpenAI(
    base_url="http://localhost:11434/v1",
    api_key="ollama"
)

print(openai.models.list())
# Out:
# SyncPage[Model](data=[Model(id='llama3.2:latest', created=1768655947, object='model', owned_by='library'), Model(id='phi3:latest', created=1768637023, object='model', owned_by='library'), Model(id='gemma3:270m', created=1768636652, object='model', owned_by='library')], object='list')

# %%
message = "Hello, Llama! This is my first ever message to you! Hi!"
response = openai.chat.completions.create(model="llama3.2", messages=[{"role":"user", "content":message}])
print(response.choices[0].message.content)
# Out:
# Hello! I'm thrilled to meet you! Welcome to our conversation! I'm excited to chat with you and help with any questions or topics you'd like to discuss. Don't worry if this is your first time talking to me - I'm here to help and make our conversation as comfortable and fun as possible. How's your day going so far?

# %%
message="starting my genai journey"
response=openai.chat.completions.create(model="llama3.2",messages=[{"role":"user","content":message}])

print(response.choices[0].message.content)
# Out:
# Embarking on a GenAI (General Artificial Intelligence) journey!
#
# Congratulations on taking the first step towards exploring the vast and exciting world of AI. Here's a curated list to get you started:
#
# **Learning Resources**
#
# 1. **Books**
# 	* "Life 3.0: Being Human in the Age of Artificial Intelligence" by Max Tegmark
# 	* "Deep Learning with Python" by François Chollet
# 	* "Artificial Intelligence for Everyone" by Andrew Ng and Michael I. Jordan
# 2. **Online Courses**
# 	* Coursera's "Machine Learning" specialization by Andrew Ng
# 	* edX's "AI for Everyone" course by Microsoft
# 	* Stanford University's "CS231: Convolutional Neural Networks for Visual Recognition"
# 3. **Tutorials and Guides**
# 	* TensorFlow's official tutorials
# 	* Keras' official tutorial
# 	* PyTorch's getting started guide
#
# **Dive into GenAI topics**
#
# 1. **Machine Learning**: Learn the basics of supervised, unsupervised, and reinforcement learning.
# 2. **Deep Learning**: Explore convolutional neural networks (CNNs), recurrent neural networks (RNNs), and long short-term memory (LSTM) networks.
# 3. **Natural Language Processing (NLP)**: Study text processing, sentiment analysis, and language models.
# 4. **Computer Vision**: Learn about image classification, object detection, segmentation, and generation.
#
# **Get hands-on experience**
#
# 1. **Recreational projects**: Start with simple tasks like image classification or sentiment analysis using pre-trained models.
# 2. **Personal projects**: Apply AI to your passion projects, such as image editing, music generation, or chatbots.
#
# **Stay updated and network**
#
# 1. **Follow AI blogs and websites**: Stay up-to-date on the latest advancements in GenAI with publications like arXiv, Medium's AI Future, and Towards Data Science.
# 2. **Join online communities**: Participate in subreddits like r/MachineLearning, r/DeepLearning, and r/AI, as well as professional forums like Kaggle and Reddit's r/AI.
# 3. **Attend conferences and meetups**: Expand your networking opportunities by attending conferences like NeurIPS, IJCAI, and meetups in your local area.
#
# **Embark on your journey!**
#
# Remember that learning GenAI is a continuous process. Be patient, persistent, and stay curious. Don't hesitate to ask for help when you need it. Happy learning!
#
# What specific area of GenAI would you like to explore first?

# %%
import requests
from bs4 import BeautifulSoup

# %%
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    def __init__(self,url):

        self.url=url

        response=requests.get(url,headers=headers)

        soup=BeautifulSoup(response.content,'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        for irrelevant in soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()
        self.text = soup.body.get_text(separator="\n", strip=True)

# %%
ed = Website("https://edwarddonner.com")
print(ed.title)
print(ed.text)
# Out:
# Home - Edward Donner
# Home
# AI Curriculum
# Proficient AI Engineer
# Connect Four
# Outsmart
# An arena that pits LLMs against each other in a battle of diplomacy and deviousness
# About
# Posts
# Well, hi there.
# I’m Ed. I like writing code and experimenting with LLMs, and hopefully you’re here because you do too. I also enjoy amateur electronic music production (
# very
# amateur) and losing myself in
# Hacker News
# , nodding my head sagely to things I only half understand.
# I’m the co-founder and CTO of
# Nebula.io
# . We’re applying AI to a field where it can make a massive, positive impact: helping people discover their potential and pursue their reason for being. I’m previously the founder and CEO of AI startup untapt,
# acquired in 2021
# .
# I will happily drone on for hours about LLMs to anyone in my vicinity. My friends got fed up with my impromptu lectures, and convinced me to make some Udemy courses. To my total joy (and shock) they’ve become best-selling, top-rated courses, with 400,000 enrolled across 190 countries. The
# full curriculum is here
# . If you’re visiting from one of my courses – I’m super grateful!
# Keep in touch
# I’ll only ever contact you occasionally, and
# I’ll always aim to add value with every email.
# Thank you!
# I’ll keep you posted.
# Enter your email…
# Warning
# Stay in touch
# Submitting form
# Δ
# January 4, 2026
# AI Builder with n8n – Create Agents and Voice Agents
# November 11, 2025
# The Unique Energy of an AI Live Event
# September 15, 2025
# AI Engineering MLOps Track – Deploy AI to Production
# May 28, 2025
# Which order to take the AI courses?
# Navigation
# Home
# AI Curriculum
# Proficient AI Engineer
# Connect Four
# Outsmart
# An arena that pits LLMs against each other in a battle of diplomacy and deviousness
# About
# Posts
# Get in touch
# ed [at] edwarddonner [dot] com
# www.edwarddonner.com
# Follow me
# LinkedIn
# Twitter
# Facebook
# Subscribe to newsletter
# Type your email…
# Subscribe

# %%
system_prompt = "You are an assistant that analyzes the contents of a website \
and provides a short summary, ignoring text that might be navigation related. \
Respond in markdown."

# %%
def user_prompt_for(website):
    user_prompt=f'Take the input data from {website.title}'
    user_prompt += "\nThe contents of this website is as follows; \
please provide a short summary of this website in markdown. \
If it includes news or announcements, then summarize these too.\n\n"
    user_prompt+=website.text

    return user_prompt

# %%
print(user_prompt_for(ed))
# Out:
# Take the input data from Home - Edward Donner
# The contents of this website is as follows; please provide a short summary of this website in markdown. If it includes news or announcements, then summarize these too.
#
# Home
# AI Curriculum
# Proficient AI Engineer
# Connect Four
# Outsmart
# An arena that pits LLMs against each other in a battle of diplomacy and deviousness
# About
# Posts
# Well, hi there.
# I’m Ed. I like writing code and experimenting with LLMs, and hopefully you’re here because you do too. I also enjoy amateur electronic music production (
# very
# amateur) and losing myself in
# Hacker News
# , nodding my head sagely to things I only half understand.
# I’m the co-founder and CTO of
# Nebula.io
# . We’re applying AI to a field where it can make a massive, positive impact: helping people discover their potential and pursue their reason for being. I’m previously the founder and CEO of AI startup untapt,
# acquired in 2021
# .
# I will happily drone on for hours about LLMs to anyone in my vicinity. My friends got fed up with my impromptu lectures, and convinced me to make some Udemy courses. To my total joy (and shock) they’ve become best-selling, top-rated courses, with 400,000 enrolled across 190 countries. The
# full curriculum is here
# . If you’re visiting from one of my courses – I’m super grateful!
# Keep in touch
# I’ll only ever contact you occasionally, and
# I’ll always aim to add value with every email.
# Thank you!
# I’ll keep you posted.
# Enter your email…
# Warning
# Stay in touch
# Submitting form
# Δ
# January 4, 2026
# AI Builder with n8n – Create Agents and Voice Agents
# November 11, 2025
# The Unique Energy of an AI Live Event
# September 15, 2025
# AI Engineering MLOps Track – Deploy AI to Production
# May 28, 2025
# Which order to take the AI courses?
# Navigation
# Home
# AI Curriculum
# Proficient AI Engineer
# Connect Four
# Outsmart
# An arena that pits LLMs against each other in a battle of diplomacy and deviousness
# About
# Posts
# Get in touch
# ed [at] edwarddonner [dot] com
# www.edwarddonner.com
# Follow me
# LinkedIn
# Twitter
# Facebook
# Subscribe to newsletter
# Type your email…
# Subscribe

# %%
def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_for(website)}
    ]

# %%
def summarize(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model = "llama3.2",
        messages = messages_for(website)
    )
    return response.choices[0].message.content

# %%
print(summarize("https://edwarddonner.com"))
# Out:
# # Website Summary
# The website belongs to Edward Donner, the co-founder and CTO of Nebula.io. He is also a developer who creates AI-related courses, including a comprehensive curriculum.
#
# ## Recent News and Announcements
# - **January 4, 2026**: "AI Builder with n8n – Create Agents and Voice Agents"
# - **November 11, 2025**: "The Unique Energy of an AI Live Event"
# - **September 15, 2025**: "AI Engineering MLOps Track – Deploy AI to Production"
# - **May 28, 2025**: The website includes a recommendation for which order to take the AI courses.
#
# ## About the Website Owner
# Edward Donner is a passionate developer and entrepreneur who creates high-quality AI content. He founded AI startup untapt, which was acquired in 2021, and created best-selling Udemy courses.
